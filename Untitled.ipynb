# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A':[1,2,3,4],'B':['hey','what','is','that']})

# %%
df1
# Out:
#    A     B
# 0  1   hey
# 1  2  what
# 2  3    is
# 3  4  that

# %%
df1.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df = pd.read_csv("C:/Users/HRUTHIK/Downloads/netflix_titless.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1      NaN                    NaN              NaN
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast       country  \
# 0                                                NaN           NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year rating   duration  \
# 0                 NaN           NaN    NaN        NaN
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019        2007.0      R    158 min
# 8803       July 1, 2019        2018.0  TV-Y7  2 Seasons
# ...

# %%
df.head(300)
# Out:
#     show_id     type                  title  \
# 0        s1      NaN                    NaN
# 1        s2  TV Show          Blood & Water
# 2        s3  TV Show              Ganglands
# 3        s4  TV Show  Jailbirds New Orleans
# 4        s5  TV Show           Kota Factory
# ..      ...      ...                    ...
# 295    s296    Movie       The Paper Tigers
# 296    s297  TV Show              Hit & Run
# 297    s298  TV Show               Navarasa
# 298    s299    Movie           Quam's Money
# 299    s300    Movie              The Swarm
#
#                                               director  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                      Julien Leclercq
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8806.000000
# mean    2014.179537
# std        8.819595
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               1
# title              1
# director        2635
# cast             825
# country          832
# date_added        11
# release_year       1
# rating             5
# duration           4
# listed_in          1
# description        1
# dtype: int64

# %%
df['duration']
# Out:
# 0             NaN
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8802      158 min
# 8803    2 Seasons
# 8804       88 min
# 8805       88 min
# 8806      111 min
# Name: duration, Length: 8807, dtype: object

# %%
df[['cast','rating']]
# Out:
#                                                    cast rating
# 0                                                   NaN    NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  TV-MA
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  TV-MA
# 3                                                   NaN  TV-MA
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...  TV-MA
# ...                                                 ...    ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...      R
# 8803                                                NaN  TV-Y7
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...      R
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...     PG
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...  TV-14
#
# [8807 rows x 2 columns]

# %%
v = df[['duration','director','title']]

# %%
v
# Out:
#        duration         director                  title
# 0           NaN              NaN                    NaN
# 1     2 Seasons              NaN          Blood & Water
# 2      1 Season  Julien Leclercq              Ganglands
# 3      1 Season              NaN  Jailbirds New Orleans
# 4     2 Seasons              NaN           Kota Factory
# ...         ...              ...                    ...
# 8802    158 min    David Fincher                 Zodiac
# 8803  2 Seasons              NaN            Zombie Dumb
# 8804     88 min  Ruben Fleischer             Zombieland
# 8805     88 min     Peter Hewitt                   Zoom
# 8806    111 min      Mozez Singh                 Zubaan
#
# [8807 rows x 3 columns]

# %%
type(v)
# Out:
# pandas.core.frame.DataFrame

# %%
df['cast'][1:200:3]
# Out:
# 1      Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4      Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 10                                                   NaN
# 13     Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
#                              ...
# 187                                        Kenjiro Tsuda
# 190               Satya Dev, Priyanka Jawalkar, Brahmaji
# 193    Jung Hae-in, Koo Kyo-hwan, Kim Sung-kyun, Son ...
# 196    Addison Rae, Tanner Buchanan, Rachael Leigh Co...
# 199    Aftab Shivdasani, Natassha, Dipannita Sharma, ...
# Name: cast, Length: 67, dtype: object

# %%
df[['type','duration']][1:50:4]
# Out:
#        type   duration
# 1   TV Show  2 Seasons
# 5   TV Show   1 Season
# 9     Movie    104 min
# 13    Movie     91 min
# 17  TV Show  2 Seasons
# 21  TV Show  5 Seasons
# 25  TV Show  2 Seasons
# 29    Movie    106 min
# 33  TV Show   1 Season
# 37  TV Show   1 Season
# 41    Movie    124 min
# 45    Movie     23 min
# 49  TV Show  2 Seasons

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.iloc[1:5]
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# 2  September 24, 2021        2021.0  TV-MA   1 Season
# 3  September 24, 2021        2021.0  TV-MA   1 Season
# 4  September 24, 2021        2021.0  TV-MA  2 Seasons
#
# ...

# %%
df.iloc[0:5]
# Out:
#   show_id     type                  title         director  \
# 0      s1      NaN                    NaN              NaN
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast       country  \
# 0                                                NaN           NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year rating   duration  \
# 0                 NaN           NaN    NaN        NaN
# 1  September 24, 2021        2021.0  TV-MA  2 Seasons
# ...

# %%
df[df['type'] == 'Movie']
# Out:
#      show_id   type                             title  \
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# 13       s14  Movie  Confessions of an Invisible Girl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# 13                    Bruno Garotti
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df['release_year']>2010
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806     True
# Name: release_year, Length: 8807, dtype: bool

# %%
df['New_col'] = df['rating'] + df['cast']

# %%
df['new_col'] = df['duration'] + df['director']

# %%
df['new_col'] = df['release_year'] + 5

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1      NaN                    NaN              NaN
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN            NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['new_col2'] = df['type'] + df['listed_in']

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1      NaN                    NaN              NaN
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN            NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# listed_in        object
# description      object
# New_col          object
# new_col         float64
# new_col2         object
# dtype: object

# %%
df = df.drop(['new_col','new_col2'],axis=1)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1      NaN                    NaN              NaN
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN            NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'New_col'],
#       dtype='object')

# %%
df.shape
# Out:
# (8807, 13)

# %%
df = df.rename(columns={'duration': 'Length (in minutes)'})

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1      NaN                    NaN              NaN
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN            NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[''][0:4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 df['duration'][0:4]
#
# ...
